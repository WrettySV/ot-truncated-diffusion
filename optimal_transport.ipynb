# %%
import numpy as np
import math
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.datasets import make_swiss_roll
from sklearn.utils import shuffle
from copy import deepcopy
import pandas as pd
import tqdm
import matplotlib.pyplot as plt
from PIL import Image
import os
import random
from sklearn.model_selection import train_test_split
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
from torchvision.models import resnet18


BATCH_SIZE = 32
INPUT_DIM = 128
HIDDEN_DIM = 256
CIFAR_STATS = ((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))


def get_device():
    return torch.device("cuda" if torch.cuda.is_available() else "cpu")


def get_cifar10_loaders(batch_size=BATCH_SIZE):
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(*CIFAR_STATS),
    ])
    train_dataset = datasets.CIFAR10(root="./data", train=True, download=True, transform=transform)
    test_dataset = datasets.CIFAR10(root="./data", train=False, download=True, transform=transform)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    return train_loader, test_loader


class NeuralOT(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super().__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, input_dim),
        )

    def forward(self, x, y):
        x_mapped = self.fc(x)
        return torch.mean((x_mapped - y) ** 2)

    def transport_map(self, x):
        return self.fc(x)


def build_cifar_encoder(output_dim=INPUT_DIM):
    encoder = resnet18(pretrained=False)
    encoder.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    encoder.maxpool = nn.Identity()
    encoder.fc = nn.Linear(encoder.fc.in_features, output_dim)
    return encoder


def build_decoder():
    return nn.Sequential(
        nn.Linear(INPUT_DIM, 512),
        nn.ReLU(),
        nn.Linear(512, 4096),
        nn.ReLU(),
        nn.Unflatten(1, (256, 4, 4)),
        nn.ConvTranspose2d(256, 128, 4, stride=2, padding=1),
        nn.BatchNorm2d(128),
        nn.ReLU(),
        nn.ConvTranspose2d(128, 64, 4, stride=2, padding=1),
        nn.BatchNorm2d(64),
        nn.ReLU(),
        nn.ConvTranspose2d(64, 3, 4, stride=2, padding=1),
        nn.Tanh(),
    )


class ImprovedDiffusionModel(nn.Module):
    def __init__(self, ot_model):
        super().__init__()
        self.encoder = build_cifar_encoder()
        self.decoder = build_decoder()
        self.ot_model = ot_model

    def forward(self, x, t=None):
        x = x.view(-1, 3, 32, 32)
        encoded = self.encoder(x)
        transported = self.ot_model.transport_map(encoded)
        return self.decoder(transported)


def train_models(diffusion_model, neural_ot_model, train_loader, num_epochs=10):
    device = get_device()
    diffusion_model = diffusion_model.to(device)
    neural_ot_model = neural_ot_model.to(device)

    optimizer = optim.Adam(
        list(neural_ot_model.parameters()) + list(diffusion_model.parameters()),
        lr=1e-4,
    )
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)
    reconstruction_criterion = nn.MSELoss()

    for epoch in range(num_epochs):
        diffusion_model.train()
        neural_ot_model.train()
        total_loss = 0

        for batch_idx, (images, _) in enumerate(train_loader):
            images = images.to(device)
            optimizer.zero_grad()

            encoded = diffusion_model.encoder(images)
            ot_loss = neural_ot_model(encoded, encoded)

            reconstructed = diffusion_model(images)
            recon_loss = reconstruction_criterion(reconstructed, images)
            loss = ot_loss + recon_loss

            loss.backward()
            optimizer.step()
            total_loss += loss.item()

            if batch_idx % 100 == 0:
                print(f"Epoch: {epoch}, Batch: {batch_idx}, Loss: {loss.item():.6f}")

        scheduler.step()
        avg_loss = total_loss / len(train_loader)
        print(f"Epoch {epoch + 1}/{num_epochs}, Average Loss: {avg_loss:.6f}")

    return diffusion_model, neural_ot_model


def denormalize(img):
    return (img * 0.5 + 0.5).clip(0, 1)


def visualize_results(model, ot_model, dataloader, num_samples=5):
    device = get_device()
    model.eval()
    ot_model.eval()

    with torch.no_grad():
        images, _ = next(iter(dataloader))
        images = images[:num_samples].to(device)

        encoded = model.encoder(images)
        transported = ot_model.transport_map(encoded)
        reconstructed = model.decoder(transported)

        original_images = images.cpu().numpy()
        reconstructed_images = reconstructed.cpu().numpy()
        encoded_features = encoded.cpu().numpy()
        transported_features = transported.cpu().numpy()

        fig, axes = plt.subplots(num_samples, 4, figsize=(16, 2.5 * num_samples))
        fig.suptitle("Original → Encoded → Transported → Reconstructed", fontsize=14)

        for i in range(num_samples):
            orig_img = denormalize(np.transpose(original_images[i], (1, 2, 0)))
            axes[i, 0].imshow(orig_img)
            axes[i, 0].set_title(f"Original {i + 1}")
            axes[i, 0].axis("off")

            encoded_img = encoded_features[i].reshape(8, 16)
            axes[i, 1].imshow(encoded_img, cmap="viridis")
            axes[i, 1].set_title("Encoded Features")
            axes[i, 1].axis("off")

            transported_img = transported_features[i].reshape(8, 16)
            axes[i, 2].imshow(transported_img, cmap="viridis")
            axes[i, 2].set_title("Transported Features")
            axes[i, 2].axis("off")

            recon_img = denormalize(np.transpose(reconstructed_images[i], (1, 2, 0)))
            axes[i, 3].imshow(recon_img)
            axes[i, 3].set_title("Reconstructed")
            axes[i, 3].axis("off")

        plt.tight_layout()
        plt.show()

        plt.figure(figsize=(12, 4))

        plt.subplot(121)
        plt.hist(encoded_features.flatten(), bins=50, alpha=0.7, label="Encoded")
        plt.hist(transported_features.flatten(), bins=50, alpha=0.7, label="Transported")
        plt.title("Feature Space Distributions")
        plt.xlabel("Feature Values")
        plt.ylabel("Frequency")
        plt.legend()

        plt.subplot(122)
        plt.scatter(encoded_features.mean(0), transported_features.mean(0), alpha=0.5)
        plt.plot([-1, 1], [-1, 1], "r--")
        plt.title("Feature Space Transformation")
        plt.xlabel("Encoded Features (mean)")
        plt.ylabel("Transported Features (mean)")

        plt.tight_layout()
        plt.show()


train_loader, test_loader = get_cifar10_loaders()
neural_ot_model = NeuralOT(INPUT_DIM, HIDDEN_DIM)
diffusion_model = ImprovedDiffusionModel(neural_ot_model)

diffusion_model, neural_ot_model = train_models(diffusion_model, neural_ot_model, train_loader)
visualize_results(diffusion_model, neural_ot_model, test_loader)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:12<00:00, 14176238.08it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch: 0, Batch: 0, Loss: 1.120799
# Epoch: 0, Batch: 100, Loss: 0.193704
# Epoch: 0, Batch: 200, Loss: 0.166977
# Epoch: 0, Batch: 300, Loss: 0.108074
# Epoch: 0, Batch: 400, Loss: 0.136950
# Epoch: 0, Batch: 500, Loss: 0.131384
# Epoch: 0, Batch: 600, Loss: 0.096892
# Epoch: 0, Batch: 700, Loss: 0.116571
# Epoch: 0, Batch: 800, Loss: 0.093446
# Epoch: 0, Batch: 900, Loss: 0.102573
# Epoch: 0, Batch: 1000, Loss: 0.086982
# Epoch: 0, Batch: 1100, Loss: 0.076838
# Epoch: 0, Batch: 1200, Loss: 0.087866
# Epoch: 0, Batch: 1300, Loss: 0.098582
# Epoch: 0, Batch: 1400, Loss: 0.094267
# Epoch: 0, Batch: 1500, Loss: 0.077997
# Epoch 1/10, Average Loss: 0.118552
# Epoch: 1, Batch: 0, Loss: 0.076741
# Epoch: 1, Batch: 100, Loss: 0.079339
# Epoch: 1, Batch: 200, Loss: 0.079552
# Epoch: 1, Batch: 300, Loss: 0.076777
# Epoch: 1, Batch: 400, Loss: 0.078416
# Epoch: 1, Batch: 500, Loss: 0.056328
# Epoch: 1, Batch: 600, Loss: 0.072290
# Epoch: 1, Batch: 700, Loss: 0.062918
# Epoch: 1, Batch: 800, Loss: 0.063612
# Epoch: 1, Batch: 900, Loss: 0.079819
# Epoch: 1, Batch: 1000, Loss: 0.061156
# Epoch: 1, Batch: 1100, Loss: 0.066423
# Epoch: 1, Batch: 1200, Loss: 0.074209
# Epoch: 1, Batch: 1300, Loss: 0.060066
# Epoch: 1, Batch: 1400, Loss: 0.063230
# Epoch: 1, Batch: 1500, Loss: 0.064510
# Epoch 2/10, Average Loss: 0.069452
# Epoch: 2, Batch: 0, Loss: 0.069441
# Epoch: 2, Batch: 100, Loss: 0.058792
# Epoch: 2, Batch: 200, Loss: 0.063413
# Epoch: 2, Batch: 300, Loss: 0.058566
# Epoch: 2, Batch: 400, Loss: 0.065197
# Epoch: 2, Batch: 500, Loss: 0.073580
# Epoch: 2, Batch: 600, Loss: 0.069654
# Epoch: 2, Batch: 700, Loss: 0.061469
# Epoch: 2, Batch: 800, Loss: 0.062693
# Epoch: 2, Batch: 900, Loss: 0.067529
# Epoch: 2, Batch: 1000, Loss: 0.052522
# Epoch: 2, Batch: 1100, Loss: 0.057864
# Epoch: 2, Batch: 1200, Loss: 0.052280
# Epoch: 2, Batch: 1300, Loss: 0.057088
# Epoch: 2, Batch: 1400, Loss: 0.054180
# Epoch: 2, Batch: 1500, Loss: 0.049348
# Epoch 3/10, Average Loss: 0.059572
# Epoch: 3, Batch: 0, Loss: 0.054489
# Epoch: 3, Batch: 100, Loss: 0.064451
# Epoch: 3, Batch: 200, Loss: 0.053734
# Epoch: 3, Batch: 300, Loss: 0.057911
# Epoch: 3, Batch: 400, Loss: 0.059224
# Epoch: 3, Batch: 500, Loss: 0.057693
# Epoch: 3, Batch: 600, Loss: 0.059434
# Epoch: 3, Batch: 700, Loss: 0.064200
# Epoch: 3, Batch: 800, Loss: 0.057906
# Epoch: 3, Batch: 900, Loss: 0.056362
# Epoch: 3, Batch: 1000, Loss: 0.049423
# Epoch: 3, Batch: 1100, Loss: 0.052100
# Epoch: 3, Batch: 1200, Loss: 0.053656
# Epoch: 3, Batch: 1300, Loss: 0.050064
# Epoch: 3, Batch: 1400, Loss: 0.056351
# Epoch: 3, Batch: 1500, Loss: 0.054388
# Epoch 4/10, Average Loss: 0.053477
# Epoch: 4, Batch: 0, Loss: 0.056236
# Epoch: 4, Batch: 100, Loss: 0.051222
# Epoch: 4, Batch: 200, Loss: 0.054441
# Epoch: 4, Batch: 300, Loss: 0.055776
# Epoch: 4, Batch: 400, Loss: 0.048382
# Epoch: 4, Batch: 500, Loss: 0.060630
# Epoch: 4, Batch: 600, Loss: 0.043901
# Epoch: 4, Batch: 700, Loss: 0.045808
# Epoch: 4, Batch: 800, Loss: 0.051551
# Epoch: 4, Batch: 900, Loss: 0.055040
# Epoch: 4, Batch: 1000, Loss: 0.044295
# Epoch: 4, Batch: 1100, Loss: 0.045655
# Epoch: 4, Batch: 1200, Loss: 0.045537
# Epoch: 4, Batch: 1300, Loss: 0.055133
# Epoch: 4, Batch: 1400, Loss: 0.041883
# Epoch: 4, Batch: 1500, Loss: 0.044435
# Epoch 5/10, Average Loss: 0.048840
# Epoch: 5, Batch: 0, Loss: 0.041063
# Epoch: 5, Batch: 100, Loss: 0.048948
# Epoch: 5, Batch: 200, Loss: 0.052656
# Epoch: 5, Batch: 300, Loss: 0.049262
# Epoch: 5, Batch: 400, Loss: 0.050425
# Epoch: 5, Batch: 500, Loss: 0.048760
# Epoch: 5, Batch: 600, Loss: 0.040778
# Epoch: 5, Batch: 700, Loss: 0.049117
# Epoch: 5, Batch: 800, Loss: 0.047616
# Epoch: 5, Batch: 900, Loss: 0.047099
# Epoch: 5, Batch: 1000, Loss: 0.048993
# Epoch: 5, Batch: 1100, Loss: 0.038700
# Epoch: 5, Batch: 1200, Loss: 0.049525
# Epoch: 5, Batch: 1300, Loss: 0.051469
# Epoch: 5, Batch: 1400, Loss: 0.041130
# Epoch: 5, Batch: 1500, Loss: 0.042092
# Epoch 6/10, Average Loss: 0.045519
# Epoch: 6, Batch: 0, Loss: 0.039835
# Epoch: 6, Batch: 100, Loss: 0.037678
# Epoch: 6, Batch: 200, Loss: 0.042123
# Epoch: 6, Batch: 300, Loss: 0.040848
# Epoch: 6, Batch: 400, Loss: 0.036587
# Epoch: 6, Batch: 500, Loss: 0.044094
# Epoch: 6, Batch: 600, Loss: 0.050685
# Epoch: 6, Batch: 700, Loss: 0.038207
# Epoch: 6, Batch: 800, Loss: 0.043148
# Epoch: 6, Batch: 900, Loss: 0.051604
# Epoch: 6, Batch: 1000, Loss: 0.041929
# Epoch: 6, Batch: 1100, Loss: 0.044663
# Epoch: 6, Batch: 1200, Loss: 0.044514
# Epoch: 6, Batch: 1300, Loss: 0.040645
# Epoch: 6, Batch: 1400, Loss: 0.044567
# Epoch: 6, Batch: 1500, Loss: 0.053356
# Epoch 7/10, Average Loss: 0.043173
# Epoch: 7, Batch: 0, Loss: 0.046759
# Epoch: 7, Batch: 100, Loss: 0.041280
# Epoch: 7, Batch: 200, Loss: 0.049035
# Epoch: 7, Batch: 300, Loss: 0.040896
# Epoch: 7, Batch: 400, Loss: 0.048787
# Epoch: 7, Batch: 500, Loss: 0.036658
# Epoch: 7, Batch: 600, Loss: 0.044759
# Epoch: 7, Batch: 700, Loss: 0.042285
# Epoch: 7, Batch: 800, Loss: 0.044858
# Epoch: 7, Batch: 900, Loss: 0.042071
# Epoch: 7, Batch: 1000, Loss: 0.037041
# Epoch: 7, Batch: 1100, Loss: 0.041351
# Epoch: 7, Batch: 1200, Loss: 0.036072
# Epoch: 7, Batch: 1300, Loss: 0.039673
# Epoch: 7, Batch: 1400, Loss: 0.043173
# Epoch: 7, Batch: 1500, Loss: 0.042762
# Epoch 8/10, Average Loss: 0.041303
# Epoch: 8, Batch: 0, Loss: 0.039094
# Epoch: 8, Batch: 100, Loss: 0.039895
# Epoch: 8, Batch: 200, Loss: 0.035360
# Epoch: 8, Batch: 300, Loss: 0.036105
# Epoch: 8, Batch: 400, Loss: 0.041403
# Epoch: 8, Batch: 500, Loss: 0.038765
# Epoch: 8, Batch: 600, Loss: 0.031624
# Epoch: 8, Batch: 700, Loss: 0.043775
# Epoch: 8, Batch: 800, Loss: 0.041001
# Epoch: 8, Batch: 900, Loss: 0.038127
# Epoch: 8, Batch: 1000, Loss: 0.036890
# Epoch: 8, Batch: 1100, Loss: 0.037887
# Epoch: 8, Batch: 1200, Loss: 0.038629
# Epoch: 8, Batch: 1300, Loss: 0.034810
# Epoch: 8, Batch: 1400, Loss: 0.039086
# Epoch: 8, Batch: 1500, Loss: 0.042427
# Epoch 9/10, Average Loss: 0.039956
# Epoch: 9, Batch: 0, Loss: 0.045317
# Epoch: 9, Batch: 100, Loss: 0.041381
# Epoch: 9, Batch: 200, Loss: 0.040665
# Epoch: 9, Batch: 300, Loss: 0.040830
# Epoch: 9, Batch: 400, Loss: 0.040199
# Epoch: 9, Batch: 500, Loss: 0.041444
# Epoch: 9, Batch: 600, Loss: 0.038550
# Epoch: 9, Batch: 700, Loss: 0.035033
# Epoch: 9, Batch: 800, Loss: 0.042279
# Epoch: 9, Batch: 900, Loss: 0.039416
# Epoch: 9, Batch: 1000, Loss: 0.039331
# Epoch: 9, Batch: 1100, Loss: 0.038461
# Epoch: 9, Batch: 1200, Loss: 0.045602
# Epoch: 9, Batch: 1300, Loss: 0.037040
# Epoch: 9, Batch: 1400, Loss: 0.035799
# Epoch: 9, Batch: 1500, Loss: 0.039576
# Epoch 10/10, Average Loss: 0.039252
